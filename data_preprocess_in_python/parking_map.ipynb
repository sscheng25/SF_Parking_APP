# %%
import pandas as pd
import numpy as np
import geopandas as gpd

# %%
onStreet = gpd.read_file('C:/Users/CSS/Desktop/MUSA611/final-project/parkingMeters.geojson')
offStreet = gpd.read_file('C:/Users/CSS/Desktop/MUSA611/final-project/OffstreetParking.geojson')
offStreet
# Out:
#    mc_entry_lanes facility_type  \
# 0             0.0             L
# 1             0.0             L
# 2             0.0             G
# 3             0.0             L
# 4             0.0             G
# 5             0.0             L
# 6             0.0             G
# 7             0.0             L
# 8             0.0             L
# 9             0.0             L
# 10            0.0             L
# 11            0.0             G
# 12            0.0             L
# 13            0.0             G
# 14            0.0             G
# 15            0.0             G
# 16            0.0             G
# 17            0.0             G
# 18            0.0             L
# 19            0.0             L
# 20            0.0             G
# 21            0.0             G
# 22            0.0             L
# 23            0.0             G
# 24            0.0             G
# 25            0.0             L
# 26            1.0             G
# 27            0.0             L
# ...

# %%
onStreet_sample = onStreet.sample(3000)
onStreet_sample
# Out:
#       jurisdiction          collection_subroute_desc smart_meter_flag  \
# 6948         SFMTA                24th St/Castro/Noe                Y
# 4260         SFMTA  9th-11th Brannan Bryant Harrison                Y
# 4064         SFMTA                              None                Y
# 9765         SFMTA                       Bryant: 600                Y
# 2117         SFMTA                  Townsend/Alameda                Y
# ...            ...                               ...              ...
# 932          SFMTA                            Leland                Y
# 2636         SFMTA       Sansome: Unit - 800 Halleck                Y
# 16602        SFMTA            California: Unit - 700                Y
# 18395        SFMTA                 Mission 2500-2700                Y
# 3906         SFMTA                          Columbus                Y
#
#       legislation_ref pmr_route parity_digit_position       latitude  \
# ...

# %%
onStreet_sample = onStreet_sample[['post_id', 'geometry']]

# %%
onStreet_sample.plot()
# Out:
# <AxesSubplot:>

# %%
onStreet_sample.to_file("C:/Users/CSS/Desktop/MUSA611/final-project/OnstreetParking.geojson", driver="GeoJSON")
