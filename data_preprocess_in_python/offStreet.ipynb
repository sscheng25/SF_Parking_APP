# %%
import pandas as pd
import geopandas as gpd
import numpy as np

# %%
offStreet = gpd.read_file('./OffstreetParking.geojson')

# %%
offStreet = offStreet[offStreet['location'] != 'The Embarcadero north of Ferry Bldg']

# %%
offStreet
# Out:
#    mc_entry_lanes facility_type  \
# 0             0.0             L
# 1             0.0             L
# 2             0.0             G
# 4             0.0             G
# 5             0.0             L
# 6             0.0             G
# 7             0.0             L
# 8             0.0             L
# 9             0.0             L
# 10            0.0             L
# 11            0.0             G
# 12            0.0             L
# 13            0.0             G
# 14            0.0             G
# 15            0.0             G
# 16            0.0             G
# 17            0.0             G
# 18            0.0             L
# 19            0.0             L
# 20            0.0             G
# 21            0.0             G
# 22            0.0             L
# 23            0.0             G
# 24            0.0             G
# 25            0.0             L
# 26            1.0             G
# 27            0.0             L
# 28            0.0             G
# ...

# %%
offStreet.dtypes
# Out:
# mc_entry_lanes           object
# facility_type            object
# services                 object
# no_key_valet_fee         object
# location                 object
# system                   object
# web_site                 object
# main_entrance_lat        object
# veh_entry_lanes          object
# validation_pgm           object
# mc_exit_lanes            object
# objectid                 object
# globalid                 object
# sp_evt_rates             object
# meter_flag               object
# main_entrance_long       object
# pm_district_id           object
# area_type                object
# reopen_fee               object
# osp_id                   object
# hi_vol_disc_flag         object
# activation_fee           object
# street_seg_ctrln_id      object
# data_feed_flag           object
# facility_name            object
# veh_exit_lanes           object
# street_address           object
# owner                    object
# late_fee                 object
# ...

# %%
offStreet.to_file("C:/Users/CSS/Desktop/MUSA611/final-project/offStreet_new.geojson", driver="GeoJSON")
